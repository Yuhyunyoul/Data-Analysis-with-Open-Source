# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuhyunyoul/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)

## CSV 형식 저장
df.to_csv('student_analysis.csv' , encoding='utf-8', index=False)

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open('output.json' , mode='w' , encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

## json.dumps를 이용한 저장
json_str = json.dumps(data, indent=4, ensure_ascii=False)


## DataFrame을 이용한 저장
df = pd.DataFrame([data])
df.to_json('outpu_df.json' , orient='columns' , indent=4, force_ascii=False)

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)

## DataFrame 인덱스 출력
print(df.index)
## DataFrame 컬럼 출력
print(df.columns)

## DataFrame 행 출력
print(df.values.tolist())
print(df.values)

## DataFrame 값 출력
print(df.values.flatten())
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
# [['김철수', 1, 4.2, '컴퓨터학', '프로그래밍'], ['이영희', 2, 3.8, '경영학', '독서토론'], ['박민수', 3, 4.5, '농학', '로봇공학'], ['최지훈', 4, 3.9, '교육학', '봉사활동'], ['정소희', 2, 3.5, '영어영문학', '음악감상']]
# [['김철수' 1 4.2 '컴퓨터학' '프로그래밍']
#  ['이영희' 2 3.8 '경영학' '독서토론']
#  ['박민수' 3 4.5 '농학' '로봇공학']
#  ['최지훈' 4 3.9 '교육학' '봉사활동']
#  ['정소희' 2 3.5 '영어영문학' '음악감상']]
# ['김철수' 1 4.2 '컴퓨터학' '프로그래밍' '이영희' 2 3.8 '경영학' '독서토론' '박민수' 3 4.5 '농학'
#  '로봇공학' '최지훈' 4 3.9 '교육학' '봉사활동' '정소희' 2 3.5 '영어영문학' '음악감상']

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv('students.csv')
df3 = pd.read_json('students.json')


## 세가지 방법 결과 비교
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df1 = pd.DataFrame.from_dict(data)

## CSV 형식으로 저장

## CSV, JSON 형식으로 저장
df.to_csv('students_scores.csv')
df.to_json('students_scores.json')

## HTML 형식으로 저장
html_table = df.to_html()
with open('students_scores.html', 'w') as f:
    f.write(html_table)

## Excel 형식으로 저장

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
import requests

url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty"
api_key = '152d8f06aab7653a036d8971405ca4f37ebc0aa2d898863fca0b3b0af3ea2c37'

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력
print(response.json())
# Out:
# {'response': {'body': {'totalCount': 40, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '31', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '11', 'khaiGrade': '1', 'pm25Value': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.019', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.017'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '26', 'so2Value': '0.003', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '14', 'khaiGrade': '1', 'pm25Value': '5', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.015', 'stationName': '한강대로', 'pm10Grade': '1', 'o3Value': '0.016'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '34', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '9', 'khaiGrade': '1', 'pm25Value': '3', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.016', 'stationName': '종로구', 'pm10Grade': '1', 'o3Value': '0.021'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '30', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '16', 'khaiGrade': '1', 'pm25Value': '3', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.018', 'stationName': '청계천로', 'pm10Grade': '1', 'o3Value': '0.016'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '-', 'so2Value': '0.002', 'coValue': '0.4', 'pm25Flag': '통신장애', 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '14', 'khaiGrade': None, 'pm25Value': '-', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': None, 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.023', 'stationName': '종로', 'pm10Grade': '1', 'o3Value': '0.010'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '28', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '12', 'khaiGrade': '1', 'pm25Value': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.014', 'stationName': '용산구', 'pm10Grade': '1', 'o3Value': '0.017'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '29', 'so2Value': '0.003', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '14', 'khaiGrade': '1', 'pm25Value': '3', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.015', 'stationName': '광진구', 'pm10Grade': '1', 'o3Value': '0.018'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '31', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '9', 'khaiGrade': '1', 'pm25Value': '5', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.013', 'stationName': '성동구', 'pm10Grade': '1', 'o3Value': '0.019'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '35', 'so2Value': '0.003', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '10', 'khaiGrade': '1', 'pm25Value': '4', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '강변북로', 'pm10Grade': '1', 'o3Value': '0.021'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '37', 'so2Va ...

# %%
response.json()
# Out:
# {'response': {'body': {'totalCount': 40,
#    'items': [{'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '31',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '11',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.019',
#      'stationName': '중구',
#      'pm10Grade': '1',
#      'o3Value': '0.017'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '26',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '14',
#      'khaiGrade': '1',
#      'pm25Value': '5',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.015',
#      'stationName': '한강대로',
#      'pm10Grade': '1',
#      'o3Value': '0.016'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '34',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '9',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.016',
#      'stationName': '종로구',
#      'pm10Grade': '1',
#      'o3Value': '0.021'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '30',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '16',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.018',
#      'stationName': '청계천로',
#      'pm10Grade': '1',
#      'o3Value': '0.016'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '-',
#      'so2Value': '0.002',
#      'coValue': '0.4',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '14',
#      'khaiGrade': None,
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': None,
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.023',
#      'stationName': '종로',
#      'pm10Grade': '1',
#      'o3Value': '0.010'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '28',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '용산구',
#      'pm10Grade': '1',
#      'o3Value': '0.017'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '29',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '14',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.015',
#      'stationName': '광진구',
#      'pm10Grade': '1',
#      'o3Value': '0.018'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '31',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '9',
#      'khaiGrade': '1',
#      'pm25Value': '5',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.013',
#      'stationName': '성동구',
#      'pm10Grade': '1',
#      'o3Value': '0.019'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '35',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '10',
#      'khaiGrade': '1',
#      'pm25Value': '4',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '강변북로',
#      'pm10Grade': '1',
#      'o3Value': '0.021'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '37',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '11',
#      'khaiGrade': '1',
#      'pm25Value': '1',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '중랑구',
#      'pm10Grade': '1',
#      'o3Value': '0.022'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '29',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '13',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.017',
#      'stationName': '동대문구',
#      'pm10Grade': '1',
#      'o3Value': '0.018'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '-',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '10',
#      'khaiGrade': None,
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': None,
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.016',
#      'stationName': '홍릉로',
#      'pm10Grade': '1',
#      'o3Value': '0.018'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '29',
#      'so2Value': '0.003',
#      'coValue': '0.1',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '8',
#      'khaiGrade': '1',
#      'pm25Value': '4',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.013',
#      'stationName': '성북구',
#      'pm10Grade': '1',
#      'o3Value': '0.017'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '-',
#      'so2Value': '0.003',
#      'coValue': '0.4',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '15',
#      'khaiGrade': None,
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': None,
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.028',
#      'stationName': '정릉로',
#      'pm10Grade': '1',
#      'o3Value': '0.009'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '25',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '13',
#      'khaiGrade': '1',
#      'pm25Value': '5',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.015',
#      'stationName': '도봉구',
#      'pm10Grade': '1',
#      'o3Value': '0.015'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '43',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '9',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.006',
#      'stationName': '은평구',
#      'pm10Grade': '1',
#      'o3Value': '0.026'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '43',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '10',
#      'khaiGrade': '1',
#      'pm25Value': '7',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.006',
#      'stationName': '서대문구',
#      'pm10Grade': '1',
#      'o3Value': '0.026'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '31',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '마포구',
#      'pm10Grade': '1',
#      'o3Value': '0.019'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '30',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '14',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.015',
#      'stationName': '신촌로',
#      'pm10Grade': '1',
#      'o3Value': '0.018'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '34',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.012',
#      'stationName': '강서구',
#      'pm10Grade': '1',
#      'o3Value': '0.021'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '41',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '13',
#      'khaiGrade': '1',
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.024',
#      'stationName': '공항대로',
#      'pm10Grade': '1',
#      'o3Value': '0.012'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '26',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '17',
#      'khaiGrade': '1',
#      'pm25Value': '6',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.016',
#      'stationName': '구로구',
#      'pm10Grade': '1',
#      'o3Value': '0.014'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '27',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '4',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.016',
#      'stationName': '영등포구',
#      'pm10Grade': '1',
#      'o3Value': '0.016'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '33',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '14',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.020',
#      'stationName': '영등포로',
#      'pm10Grade': '1',
#      'o3Value': '0.013'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '27',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.016',
#      'stationName': '동작구',
#      'pm10Grade': '1',
#      'o3Value': '0.016'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '52',
#      'so2Value': '0.002',
#      'coValue': '0.4',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '18',
#      'khaiGrade': '2',
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '2',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.031',
#      'stationName': '동작대로 중앙차로',
#      'pm10Grade': '1',
#      'o3Value': '0.006'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '31',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '10',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.013',
#      'stationName': '관악구',
#      'pm10Grade': '1',
#      'o3Value': '0.018'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '36',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.022',
#      'stationName': '강남구',
#      'pm10Grade': '1',
#      'o3Value': '0.010'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '32',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '14',
#      'khaiGrade': '1',
#      'pm25Value': '6',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.019',
#      'stationName': '서초구',
#      'pm10Grade': '1',
#      'o3Value': '0.012'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '32',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '22',
#      'khaiGrade': '1',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.019',
#      'stationName': '도산대로',
#      'pm10Grade': '1',
#      'o3Value': '0.012'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '47',
#      'so2Value': '0.003',
#      'coValue': '0.5',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '14',
#      'khaiGrade': '1',
#      'pm25Value': '5',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': None,
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.028',
#      'stationName': '강남대로',
#      'pm10Grade': '1',
#      'o3Value': '0.007'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '29',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '11',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.017',
#      'stationName': '송파구',
#      'pm10Grade': '1',
#      'o3Value': '0.018'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '25',
#      'so2Value': '0.002',
#      'coValue': '0.6',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '16',
#      'khaiGrade': '1',
#      'pm25Value': '2',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '강동구',
#      'pm10Grade': '1',
#      'o3Value': '0.014'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '-',
#      'so2Value': '0.002',
#      'coValue': '0.4',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '11',
#      'khaiGrade': None,
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': None,
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.021',
#      'stationName': '천호대로',
#      'pm10Grade': '1',
#      'o3Value': '0.009'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '30',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '7',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '금천구',
#      'pm10Grade': '1',
#      'o3Value': '0.018'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '51',
#      'so2Value': '0.003',
#      'coValue': '0.4',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '15',
#      'khaiGrade': '2',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '2',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.030',
#      'stationName': '시흥대로',
#      'pm10Grade': '1',
#      'o3Value': '0.008'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '36',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '9',
#      'khaiGrade': '1',
#      'pm25Value': '1',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.010',
#      'stationName': '강북구',
#      'pm10Grade': '1',
#      'o3Value': '0.021'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '28',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '12',
#      'khaiGrade': '1',
#      'pm25Value': '1',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.016',
#      'stationName': '양천구',
#      'pm10Grade': '1',
#      'o3Value': '0.017'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '44',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '9',
#      'khaiGrade': '1',
#      'pm25Value': '1',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.009',
#      'stationName': '노원구',
#      'pm10Grade': '1',
#      'o3Value': '0.027'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '42',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '13',
#      'khaiGrade': '1',
#      'pm25Value': '4',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-19 08:00',
#      'coGrade': '1',
#      'no2Value': '0.025',
#      'stationName': '화랑로',
#      'pm10Grade': '1',
#      'o3Value': '0.012'}],
#    'pageNo': 1,
#    'numOfRows': 100},
#   'header': {'resultMsg': 'NORMAL_CODE', 'resultCode': '00'}}}

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()['response']['body']['items']
print(type(data))
print(len(data))
print(data[0])
df = pd.DataFrame(data)
df['pm25Grade']
# Out:
# <class 'list'>
# 40
# {'so2Grade': '1', 'coFlag': None, 'khaiValue': '31', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '11', 'khaiGrade': '1', 'pm25Value': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-19 08:00', 'coGrade': '1', 'no2Value': '0.019', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.017'}
# 0        1
# 1        1
# 2        1
# 3        1
# 4     None
# 5        1
# 6        1
# 7        1
# 8        1
# 9        1
# 10       1
# 11    None
# 12       1
# 13    None
# 14       1
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# 20       1
# 21       1
# 22       1
# 23       1
# 24       1
# 25       1
# 26       1
# 27       1
# 28       1
# 29       1
# 30    None
# 31       1
# 32       1
# 33    None
# 34       1
# 35       1
# 36       1
# 37       1
# 38       1
# 39       1
# Name: pm25Grade, dtype: object

# %% [markdown]
# ## 다양항 형식으로 데이터 저장

# %%
##CSV 형식 데이터 저장
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장
df.to_json('air_pollution.json' ,indent=4, force_ascii=False)
## EXCEL 형식 데이터 저장
df.to_excel('air_pollution.xlsx' ,index=False)
## HTML 형식 데이터 저장
df.to_html('air_pollution.html')
